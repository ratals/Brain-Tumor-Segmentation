# %%
import os
import cv2
import random
import glob
import PIL
import shutil
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from skimage import data
from skimage.util import montage
import skimage.transform as skTrans
from skimage.transform import rotate
from skimage.transform import resize
from PIL import Image, ImageOps
import nibabel as nib
import keras
from keras import backend as K
# import keras.backend as K
from keras.callbacks import CSVLogger
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras import preprocessing

# %%
TRAIN_DATASET_PATH = "/content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/"

# %%
old_name = TRAIN_DATASET_PATH + "BraTS20_Training_355/W39_1998.09.19_Segm.nii"
new_name = TRAIN_DATASET_PATH + "BraTS20_Training_355/BraTS20_Training_355_seg.nii"

# renaming the file
try:
    os.rename(old_name, new_name)
    print("File has been re-named successfully!")
except:
    print("File is already renamed!")
# Out:
# File has been re-named successfully!

# %%
# load .nii file as a numpy array
test_image_flair = nib.load(TRAIN_DATASET_PATH + "BraTS20_Training_355/BraTS20_Training_355_flair.nii").get_fdata()
print("Shape: ", test_image_flair.shape)
print("Dtype: ", test_image_flair.dtype)
# Out:
# Shape:  (240, 240, 155)
# Dtype:  float64

# %%
print("Min: ", test_image_flair.min())
print("Max: ", test_image_flair.max())
# Out:
# Min:  0.0
# Max:  1854.603271484375

# %%
scaler = MinMaxScaler()

# %%
# Scale the test_image_flair array and then reshape it back to its original dimensions.
# This ensures the data is normalized/standardized for model input without altering its spatial structure.
test_image_flair = scaler.fit_transform(test_image_flair.reshape(-1, test_image_flair.shape[-1])).reshape(test_image_flair.shape)

# %%
print("Min: ", test_image_flair.min())
print("Max: ", test_image_flair.max())
# Out:
# Min:  0.0
# Max:  1.0

# %%
# rescaling t1
test_image_t1 = nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_t1.nii').get_fdata()
test_image_t1 = scaler.fit_transform(test_image_t1.reshape(-1, test_image_t1.shape[-1])).reshape(test_image_t1.shape)

# rescaling t1ce
test_image_t1ce = nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_t1ce.nii').get_fdata()
test_image_t1ce = scaler.fit_transform(test_image_t1ce.reshape(-1, test_image_t1ce.shape[-1])).reshape(test_image_t1ce.shape)

# rescaling t2
test_image_t2 = nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_t2.nii').get_fdata()
test_image_t2 = scaler.fit_transform(test_image_t2.reshape(-1, test_image_t2.shape[-1])).reshape(test_image_t2.shape)

# we will not rescale the mask
test_image_seg = nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_seg.nii').get_fdata()

# %%
slice = 95

print("Slice Number: " + str(slice))

plt.figure(figsize=(12, 8))

# T1
plt.subplot(2, 3, 1)
plt.imshow(test_image_t1[:,:,slice], cmap='gray')
plt.title('T1')

# T1ce
plt.subplot(2, 3, 2)
plt.imshow(test_image_t1ce[:,:,slice], cmap='gray')
plt.title('T1ce')

# T2
plt.subplot(2, 3, 3)
plt.imshow(test_image_t2[:,:,slice], cmap='gray')
plt.title('T2')

# Flair
plt.subplot(2, 3, 4)
plt.imshow(test_image_flair[:,:,slice], cmap='gray')
plt.title('FLAIR')

# Mask
plt.subplot(2, 3, 5)
plt.imshow(test_image_seg[:,:,slice])
plt.title('Mask')
plt.show()
# Out:
# Slice Number: 95

# %%
# Modality shape
print("Modality: ", test_image_t1.shape)

# Segmentation shape
print("Segmentation: ", test_image_seg.shape)
# Out:
# Modality:  (240, 240, 155)
# Segmentation:  (240, 240, 155)

# %%
slice = 95

print("Slice number: " + str(slice))

plt.figure(figsize=(12, 8))

# Apply a 90° rotation with an automatic resizing, otherwise the display is less obvious to analyze
# T1 - Transverse View
plt.subplot(1, 3, 1)
plt.imshow(test_image_t1ce[:,:,slice], cmap='gray')
plt.title('T1 - Transverse View')

# T1 - Frontal View
plt.subplot(1, 3, 2)
plt.imshow(rotate(test_image_t1ce[:,slice,:], 90, resize=True), cmap='gray')
plt.title('T1 - Frontal View')

# T1 - Sagittal View
plt.subplot(1, 3, 3)
plt.imshow(rotate(test_image_t1ce[slice,:,:], 90, resize=True), cmap='gray')
plt.title('T1 - Sagittal View')
plt.show()
# Out:
# Slice number: 95

# %%
plt.figure(figsize=(10, 10))
plt.subplot(1, 1, 1)

# montage allows us to concatenate multiple images of the same size horizontally and vertically
plt.imshow(rotate(montage(test_image_t1ce[:,:,:]), 90, resize=True), cmap ='gray');

# %%
# Skip 50:-50 slices since there is not much to see
plt.figure(figsize=(10, 10))
plt.subplot(1, 1, 1)
plt.imshow(rotate(montage(test_image_t1ce[50:-50,:,:]), 90, resize=True), cmap ='gray');

# %%
# Skip 50:-50 slices since there is not much to see
plt.figure(figsize=(10, 10))
plt.subplot(1, 1, 1)
plt.imshow(rotate(montage(test_image_seg[50:-50,:,:]), 90, resize=True), cmap ='gray');

# %%
# Plotting the segmantation
cmap = matplotlib.colors.ListedColormap(['#440054', '#3b528b', '#18b880', '#e6d74f'])
norm = matplotlib.colors.BoundaryNorm([-0.5, 0.5, 1.5, 2.5, 3.5], cmap.N)

# plotting the 95th slice
plt.imshow(test_image_seg[:,:,95], cmap=cmap, norm=norm)
plt.colorbar()
plt.show()

# %%
# Isolation of class 0
seg_0 = test_image_seg.copy()
seg_0[seg_0 != 0] = np.nan

# Isolation of class 1
seg_1 = test_image_seg.copy()
seg_1[seg_1 != 1] = np.nan

# Isolation of class 2
seg_2 = test_image_seg.copy()
seg_2[seg_2 != 2] = np.nan

# Isolation of class 4
seg_4 = test_image_seg.copy()
seg_4[seg_4 != 4] = np.nan

# Define legend
class_names = ['class 0', 'class 1', 'class 2', 'class 4']
legend = [plt.Rectangle((0, 0), 1, 1, color=cmap(i), label=class_names[i]) for i in range(len(class_names))]

fig, ax = plt.subplots(1, 5, figsize=(20, 20))

ax[0].imshow(test_image_seg[:,:, slice], cmap=cmap, norm=norm)
ax[0].set_title('Original Segmentation')
ax[0].legend(handles=legend, loc='lower left')

ax[1].imshow(seg_0[:,:, slice], cmap=cmap, norm=norm)
ax[1].set_title('Not Tumor (class 0)')

ax[2].imshow(seg_1[:,:, slice], cmap=cmap, norm=norm)
ax[2].set_title('Non-Enhancing Tumor (class 1)')

ax[3].imshow(seg_2[:,:, slice], cmap=cmap, norm=norm)
ax[3].set_title('Edema (class 2)')

ax[4].imshow(seg_4[:,:, slice], cmap=cmap, norm=norm)
ax[4].set_title('Enhancing Tumor (class 4)')

plt.show()

# %%
# lists of directories with studies
train_and_val_directories = [f.path for f in os.scandir(TRAIN_DATASET_PATH) if f.is_dir()]

def pathListIntoIds(dirList):
    x = []
    for i in range(0,len(dirList)):
        x.append(dirList[i][dirList[i].rfind('/')+1:])
    return x

train_and_test_ids = pathListIntoIds(train_and_val_directories);

train_test_ids, val_ids = train_test_split(train_and_test_ids,test_size=0.2)
train_ids, test_ids = train_test_split(train_test_ids,test_size=0.15)

# %%
# Print data distribution (Train: 68%, Test: 12%, Val: 20%)
print(f"Train length: {len(train_ids)}")
print(f"Validation length: {len(val_ids)}")
print(f"Test length: {len(test_ids)}")
# Out:
# Train length: 250
# Validation length: 74
# Test length: 45

# %%
plt.bar(["Train","Valid","Test"],
        [len(train_ids), len(val_ids), len(test_ids)],
        align='center',
        color=[ 'green','red', 'blue'],
        label=["Train", "Valid", "Test"]
       )

plt.legend()

plt.ylabel('Number of Images')
plt.title('Data Distribution')

plt.show()

# %%
# Define seg-areas
SEGMENT_CLASSES = {
    0 : 'NOT tumor',
    1 : 'NECROTIC/CORE', # or NON-ENHANCING tumor CORE
    2 : 'EDEMA',
    3 : 'ENHANCING' # original 4 -> converted into 3
}

# Select Slices and Image Size
VOLUME_SLICES = 100
VOLUME_START_AT = 22 # first slice of volume that we will include
IMG_SIZE=128

# %%
class DataGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, dim=(IMG_SIZE,IMG_SIZE), batch_size = 1, n_channels = 2, shuffle=True, **kwargs):
        'Initialization'
        super().__init__(**kwargs)
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))
        y = np.zeros((self.batch_size*VOLUME_SLICES, 240, 240))
        Y = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, 4))


        # Generate data
        for c, i in enumerate(Batch_ids):
            case_path = os.path.join(TRAIN_DATASET_PATH, i)

            data_path = os.path.join(case_path, f'{i}_flair.nii');
            flair = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_t1ce.nii');
            t1ce = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_seg.nii');
            seg = nib.load(data_path).get_fdata()

            for j in range(VOLUME_SLICES):
                 X[j +VOLUME_SLICES*c,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));
                 X[j +VOLUME_SLICES*c,:,:,1] = cv2.resize(t1ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));

                 y[j +VOLUME_SLICES*c] = seg[:,:,j+VOLUME_START_AT];

        # Generate masks
        y[y==4] = 3;
        mask = tf.one_hot(y, 4);
        Y = tf.image.resize(mask, (IMG_SIZE, IMG_SIZE));
        return X/np.max(X), Y

training_generator = DataGenerator(train_ids)
valid_generator = DataGenerator(val_ids)
test_generator = DataGenerator(test_ids)

# %%
# Define a function to display one slice and its segmentation
def display_slice_and_segmentation(flair, t1ce, segmentation):
    fig, axes = plt.subplots(1, 3, figsize=(10, 5))

    axes[0].imshow(flair, cmap='gray')
    axes[0].set_title('Flair')
    axes[0].axis('off')

    axes[1].imshow(t1ce, cmap='gray')
    axes[1].set_title('T1CE')
    axes[1].axis('off')

    axes[2].imshow(segmentation) # Displaying segmentation
    axes[2].set_title('Segmentation')
    axes[2].axis('off')

    plt.tight_layout()
    plt.show()


# Retrieve the batch from the training generator
X_batch, Y_batch = training_generator[8]

# Extract Flair, T1CE, and segmentation from the batch
flair_batch = X_batch[:, :, :, 0]
t1ce_batch = X_batch[:, :, :, 1]
segmentation_batch = np.argmax(Y_batch, axis=-1)  # Convert one-hot encoded to categorical

# Extract the 50th slice from Flair, T1CE, and segmentation
slice_index = 60  # Indexing starts from 0
slice_flair = flair_batch[slice_index]
slice_t1ce = t1ce_batch[slice_index]
slice_segmentation = segmentation_batch[slice_index]

# Display the 50th slice and its segmentation
display_slice_and_segmentation(slice_flair, slice_t1ce, slice_segmentation)

# %%
import tensorflow as tf

# %%
# dice loss as defined above for 4 classes
def dice_coef(y_true, y_pred, smooth=1.0):
  class_num = 4
  for i in range(class_num):
    # y_true_f = tf.keras.backend.flatten(y_true[:,:,:,i])

    y_true_f = tf.keras.backend.flatten(y_true[:,:,:,i])
    y_pred_f = tf.keras.backend.flatten(y_pred[:,:,:,i])
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    loss = ((2. * intersection + smooth) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + smooth))
    if i == 0:
        total_loss = loss
    else:
        total_loss = total_loss + loss
  total_loss = total_loss / class_num
  return total_loss

# %%
# Define per class evaluation of dice coef
def dice_coef_necrotic(y_true, y_pred, epsilon=1e-6):
    intersection = tf.keras.backend.sum(tf.keras.backend.abs(y_true[:,:,:,1] * y_pred[:,:,:,1]))
    return (2. * intersection) / (tf.keras.backend.sum(tf.keras.backend.square(y_true[:,:,:,1])) + tf.keras.backend.sum(tf.keras.backend.square(y_pred[:,:,:,1])) + epsilon)

def dice_coef_edema(y_true, y_pred, epsilon=1e-6):
    intersection = tf.keras.backend.sum(tf.keras.backend.abs(y_true[:,:,:,2] * y_pred[:,:,:,2]))
    return (2. * intersection) / (tf.keras.backend.sum(tf.keras.backend.square(y_true[:,:,:,2])) + tf.keras.backend.sum(tf.keras.backend.square(y_pred[:,:,:,2])) + epsilon)

def dice_coef_enhancing(y_true, y_pred, epsilon=1e-6):
    intersection = tf.keras.backend.sum(tf.keras.backend.abs(y_true[:,:,:,3] * y_pred[:,:,:,3]))
    return (2. * intersection) / (tf.keras.backend.sum(tf.keras.backend.square(y_true[:,:,:,3])) + tf.keras.backend.sum(tf.keras.backend.square(y_pred[:,:,:,3])) + epsilon)

# %%
# Computing Precision
def precision(y_true, y_pred):
        true_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true * y_pred, 0, 1)))
        predicted_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
        return precision


# Computing Sensitivity
def sensitivity(y_true, y_pred):
    true_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true * y_pred, 0, 1)))
    possible_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())


# Computing Specificity
def specificity(y_true, y_pred):
    true_negatives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + tf.keras.backend.epsilon())

# %%
def build_unet(inputs, ker_init, dropout):
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(inputs)
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv1)

    pool = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    pool1 = MaxPooling2D(pool_size=(2, 2))(conv)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv2)

    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv3)


    pool4 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool4)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv5)
    drop5 = Dropout(dropout)(conv5)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(drop5))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)

    up = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv9))
    merge = concatenate([conv1,up], axis = 3)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    conv10 = Conv2D(4, (1,1), activation = 'softmax')(conv)

    return Model(inputs = inputs, outputs = conv10)

# %%
input_layer = Input((IMG_SIZE, IMG_SIZE, 2))

model = build_unet(input_layer, 'he_normal', 0.2)

model.compile(loss="categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=0.001),
              metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, dice_coef_edema ,dice_coef_enhancing])

# %%
plot_model(model,
           show_shapes = True,
           show_dtype=False,
           show_layer_names = True,
           rankdir = 'TB',
           expand_nested = False,
           dpi = 70)

# %%
callbacks = [
      keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                            patience=2, min_lr=0.000001, verbose=1),
      keras.callbacks.ModelCheckpoint(filepath = 'model_.{epoch:02d}-{val_loss:.6f}.weights.h5',
                                      verbose=1, save_best_only=True, save_weights_only = True),
      CSVLogger('training.log', separator=',', append=False)
    ]

# %%
tf.keras.backend.clear_session()

history =  model.fit(training_generator,
                    epochs=35,
                    steps_per_epoch=len(train_ids),
                    callbacks= callbacks,
                    validation_data = valid_generator
                    )
# Out:
# Epoch 1/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 585ms/step - accuracy: 0.9800 - dice_coef: 0.2490 - dice_coef_edema: 0.0828 - dice_coef_enhancing: 0.0353 - dice_coef_necrotic: 0.0426 - loss: 0.5421 - mean_io_u: 0.4777 - precision: 0.9575 - sensitivity: 0.8967 - specificity: 0.9945
# Epoch 1: val_loss improved from inf to 0.07085, saving model to model_.01-0.070855.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 298s 944ms/step - accuracy: 0.9800 - dice_coef: 0.2490 - dice_coef_edema: 0.0830 - dice_coef_enhancing: 0.0353 - dice_coef_necrotic: 0.0426 - loss: 0.5407 - mean_io_u: 0.4777 - precision: 0.9576 - sensitivity: 0.8970 - specificity: 0.9945 - val_accuracy: 0.9839 - val_dice_coef: 0.2773 - val_dice_coef_edema: 0.1855 - val_dice_coef_enhancing: 0.0680 - val_dice_coef_necrotic: 0.0839 - val_loss: 0.0709 - val_mean_io_u: 0.4727 - val_precision: 0.9837 - val_sensitivity: 0.9837 - val_specificity: 0.9946 - learning_rate: 0.0010
# Epoch 2/35
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# Epoch 2: val_loss did not improve from 0.07085
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 139ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9839 - val_dice_coef: 0.2773 - val_dice_coef_edema: 0.1855 - val_dice_coef_enhancing: 0.0680 - val_dice_coef_necrotic: 0.0839 - val_loss: 0.0709 - val_mean_io_u: 0.4727 - val_precision: 0.9837 - val_sensitivity: 0.9837 - val_specificity: 0.9946 - learning_rate: 0.0010
# Epoch 3/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 618ms/step - accuracy: 0.9825 - dice_coef: 0.2806 - dice_coef_edema: 0.1573 - dice_coef_enhancing: 0.0772 - dice_coef_necrotic: 0.0798 - loss: 0.0718 - mean_io_u: 0.4920 - precision: 0.9825 - sensitivity: 0.9822 - specificity: 0.9942
# Epoch 3: val_loss improved from 0.07085 to 0.06333, saving model to model_.03-0.063332.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 188s 732ms/step - accuracy: 0.9825 - dice_coef: 0.2806 - dice_coef_edema: 0.1574 - dice_coef_enhancing: 0.0772 - dice_coef_necrotic: 0.0798 - loss: 0.0717 - mean_io_u: 0.4921 - precision: 0.9825 - sensitivity: 0.9822 - specificity: 0.9942 - val_accuracy: 0.9839 - val_dice_coef: 0.2928 - val_dice_coef_edema: 0.2149 - val_dice_coef_enhancing: 0.1145 - val_dice_coef_necrotic: 0.1065 - val_loss: 0.0633 - val_mean_io_u: 0.4143 - val_precision: 0.9842 - val_sensitivity: 0.9836 - val_specificity: 0.9947 - learning_rate: 0.0010
# Epoch 4/35
#
# Epoch 4: val_loss did not improve from 0.06333
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 109ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9839 - val_dice_coef: 0.2928 - val_dice_coef_edema: 0.2149 - val_dice_coef_enhancing: 0.1145 - val_dice_coef_necrotic: 0.1065 - val_loss: 0.0633 - val_mean_io_u: 0.4143 - val_precision: 0.9842 - val_sensitivity: 0.9836 - val_specificity: 0.9947 - learning_rate: 0.0010
# Epoch 5/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 599ms/step - accuracy: 0.9834 - dice_coef: 0.3022 - dice_coef_edema: 0.2116 - dice_coef_enhancing: 0.1425 - dice_coef_necrotic: 0.1116 - loss: 0.0629 - mean_io_u: 0.4881 - precision: 0.9849 - sensitivity: 0.9802 - specificity: 0.9950
# Epoch 5: val_loss improved from 0.06333 to 0.05882, saving model to model_.05-0.058816.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 182s 714ms/step - accuracy: 0.9834 - dice_coef: 0.3023 - dice_coef_edema: 0.2116 - dice_coef_enhancing: 0.1425 - dice_coef_necrotic: 0.1116 - loss: 0.0629 - mean_io_u: 0.4881 - precision: 0.9849 - sensitivity: 0.9802 - specificity: 0.9950 - val_accuracy: 0.9839 - val_dice_coef: 0.2998 - val_dice_coef_edema: 0.1795 - val_dice_coef_enhancing: 0.0617 - val_dice_coef_necrotic: 0.1244 - val_loss: 0.0588 - val_mean_io_u: 0.5000 - val_precision: 0.9852 - val_sensitivity: 0.9832 - val_specificity: 0.9951 - learning_rate: 0.0010
# Epoch 6/35
#
# Epoch 6: val_loss did not improve from 0.05882
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 31s 124ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9839 - val_dice_coef: 0.2998 - val_dice_coef_edema: 0.1795 - val_dice_coef_enhancing: 0.0617 - val_dice_coef_necrotic: 0.1244 - val_loss: 0.0588 - val_mean_io_u: 0.5000 - val_precision: 0.9852 - val_sensitivity: 0.9832 - val_specificity: 0.9951 - learning_rate: 0.0010
# Epoch 7/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - accuracy: 0.9840 - dice_coef: 0.2994 - dice_coef_edema: 0.2006 - dice_coef_enhancing: 0.1280 - dice_coef_necrotic: 0.1109 - loss: 0.0622 - mean_io_u: 0.5138 - precision: 0.9858 - sensitivity: 0.9813 - specificity: 0.9953
# Epoch 7: val_loss improved from 0.05882 to 0.04816, saving model to model_.07-0.048156.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 231s 712ms/step - accuracy: 0.9840 - dice_coef: 0.2994 - dice_coef_edema: 0.2006 - dice_coef_enhancing: 0.1281 - dice_coef_necrotic: 0.1109 - loss: 0.0622 - mean_io_u: 0.5137 - precision: 0.9858 - sensitivity: 0.9813 - specificity: 0.9953 - val_accuracy: 0.9839 - val_dice_coef: 0.3260 - val_dice_coef_edema: 0.2686 - val_dice_coef_enhancing: 0.1575 - val_dice_coef_necrotic: 0.1711 - val_loss: 0.0482 - val_mean_io_u: 0.5000 - val_precision: 0.9884 - val_sensitivity: 0.9830 - val_specificity: 0.9961 - learning_rate: 0.0010
# Epoch 8/35
#
# Epoch 8: val_loss improved from 0.04816 to 0.04816, saving model to model_.08-0.048156.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 127ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9839 - val_dice_coef: 0.3260 - val_dice_coef_edema: 0.2686 - val_dice_coef_enhancing: 0.1575 - val_dice_coef_necrotic: 0.1711 - val_loss: 0.0482 - val_mean_io_u: 0.5000 - val_precision: 0.9884 - val_sensitivity: 0.9830 - val_specificity: 0.9961 - learning_rate: 0.0010
# Epoch 9/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 597ms/step - accuracy: 0.9841 - dice_coef: 0.3283 - dice_coef_edema: 0.2722 - dice_coef_enhancing: 0.1986 - dice_coef_necrotic: 0.1821 - loss: 0.0540 - mean_io_u: 0.4865 - precision: 0.9888 - sensitivity: 0.9813 - specificity: 0.9962
# Epoch 9: val_loss improved from 0.04816 to 0.04631, saving model to model_.09-0.046314.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 194s 763ms/step - accuracy: 0.9841 - dice_coef: 0.3283 - dice_coef_edema: 0.2722 - dice_coef_enhancing: 0.1986 - dice_coef_necrotic: 0.1820 - loss: 0.0540 - mean_io_u: 0.4866 - precision: 0.9888 - sensitivity: 0.9813 - specificity: 0.9962 - val_accuracy: 0.9856 - val_dice_coef: 0.3412 - val_dice_coef_edema: 0.2955 - val_dice_coef_enhancing: 0.1946 - val_dice_coef_necrotic: 0.1691 - val_loss: 0.0463 - val_mean_io_u: 0.5000 - val_precision: 0.9879 - val_sensitivity: 0.9839 - val_specificity: 0.9959 - learning_rate: 0.0010
# Epoch 10/35
#
# Epoch 10: val_loss did not improve from 0.04631
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 33s 132ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9856 - val_dice_coef: 0.3412 - val_dice_coef_edema: 0.2955 - val_dice_coef_enhancing: 0.1946 - val_dice_coef_necrotic: 0.1691 - val_loss: 0.0463 - val_mean_io_u: 0.5000 - val_precision: 0.9879 - val_sensitivity: 0.9839 - val_specificity: 0.9959 - learning_rate: 0.0010
# Epoch 11/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - accuracy: 0.9856 - dice_coef: 0.3485 - dice_coef_edema: 0.3748 - dice_coef_enhancing: 0.1884 - dice_coef_necrotic: 0.1986 - loss: 0.0501 - mean_io_u: 0.4857 - precision: 0.9893 - sensitivity: 0.9819 - specificity: 0.9964
# Epoch 11: val_loss improved from 0.04631 to 0.04431, saving model to model_.11-0.044309.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 183s 721ms/step - accuracy: 0.9856 - dice_coef: 0.3485 - dice_coef_edema: 0.3749 - dice_coef_enhancing: 0.1887 - dice_coef_necrotic: 0.1987 - loss: 0.0501 - mean_io_u: 0.4858 - precision: 0.9893 - sensitivity: 0.9819 - specificity: 0.9964 - val_accuracy: 0.9875 - val_dice_coef: 0.3682 - val_dice_coef_edema: 0.3717 - val_dice_coef_enhancing: 0.3725 - val_dice_coef_necrotic: 0.2576 - val_loss: 0.0443 - val_mean_io_u: 0.5000 - val_precision: 0.9929 - val_sensitivity: 0.9814 - val_specificity: 0.9975 - learning_rate: 0.0010
# Epoch 12/35
#
# Epoch 12: val_loss did not improve from 0.04431
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9875 - val_dice_coef: 0.3682 - val_dice_coef_edema: 0.3717 - val_dice_coef_enhancing: 0.3725 - val_dice_coef_necrotic: 0.2576 - val_loss: 0.0443 - val_mean_io_u: 0.5000 - val_precision: 0.9929 - val_sensitivity: 0.9814 - val_specificity: 0.9975 - learning_rate: 0.0010
# Epoch 13/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - accuracy: 0.9854 - dice_coef: 0.3614 - dice_coef_edema: 0.3547 - dice_coef_enhancing: 0.2977 - dice_coef_necrotic: 0.1936 - loss: 0.0490 - mean_io_u: 0.4859 - precision: 0.9896 - sensitivity: 0.9821 - specificity: 0.9965
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 13: val_loss did not improve from 0.04431
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 184s 724ms/step - accuracy: 0.9854 - dice_coef: 0.3614 - dice_coef_edema: 0.3547 - dice_coef_enhancing: 0.2977 - dice_coef_necrotic: 0.1936 - loss: 0.0490 - mean_io_u: 0.4860 - precision: 0.9896 - sensitivity: 0.9821 - specificity: 0.9965 - val_accuracy: 0.9861 - val_dice_coef: 0.3535 - val_dice_coef_edema: 0.3352 - val_dice_coef_enhancing: 0.3526 - val_dice_coef_necrotic: 0.2041 - val_loss: 0.0477 - val_mean_io_u: 0.5000 - val_precision: 0.9910 - val_sensitivity: 0.9821 - val_specificity: 0.9969 - learning_rate: 0.0010
# Epoch 14/35
#
# Epoch 14: val_loss did not improve from 0.04431
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 127ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9861 - val_dice_coef: 0.3535 - val_dice_coef_edema: 0.3352 - val_dice_coef_enhancing: 0.3526 - val_dice_coef_necrotic: 0.2041 - val_loss: 0.0477 - val_mean_io_u: 0.5000 - val_precision: 0.9910 - val_sensitivity: 0.9821 - val_specificity: 0.9969 - learning_rate: 2.0000e-04
# Epoch 15/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 597ms/step - accuracy: 0.9865 - dice_coef: 0.3894 - dice_coef_edema: 0.3978 - dice_coef_enhancing: 0.3996 - dice_coef_necrotic: 0.2375 - loss: 0.0414 - mean_io_u: 0.4914 - precision: 0.9911 - sensitivity: 0.9825 - specificity: 0.9970
# Epoch 15: val_loss improved from 0.04431 to 0.03419, saving model to model_.15-0.034193.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 184s 723ms/step - accuracy: 0.9865 - dice_coef: 0.3894 - dice_coef_edema: 0.3981 - dice_coef_enhancing: 0.3997 - dice_coef_necrotic: 0.2376 - loss: 0.0414 - mean_io_u: 0.4915 - precision: 0.9911 - sensitivity: 0.9825 - specificity: 0.9970 - val_accuracy: 0.9888 - val_dice_coef: 0.4225 - val_dice_coef_edema: 0.5202 - val_dice_coef_enhancing: 0.4126 - val_dice_coef_necrotic: 0.2612 - val_loss: 0.0342 - val_mean_io_u: 0.5000 - val_precision: 0.9919 - val_sensitivity: 0.9856 - val_specificity: 0.9972 - learning_rate: 2.0000e-04
# Epoch 16/35
#
# Epoch 16: val_loss did not improve from 0.03419
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 35s 138ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9888 - val_dice_coef: 0.4225 - val_dice_coef_edema: 0.5202 - val_dice_coef_enhancing: 0.4126 - val_dice_coef_necrotic: 0.2612 - val_loss: 0.0342 - val_mean_io_u: 0.5000 - val_precision: 0.9919 - val_sensitivity: 0.9856 - val_specificity: 0.9972 - learning_rate: 2.0000e-04
# Epoch 17/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 602ms/step - accuracy: 0.9894 - dice_coef: 0.4474 - dice_coef_edema: 0.5579 - dice_coef_enhancing: 0.4872 - dice_coef_necrotic: 0.2615 - loss: 0.0318 - mean_io_u: 0.5170 - precision: 0.9924 - sensitivity: 0.9862 - specificity: 0.9974
# Epoch 17: val_loss improved from 0.03419 to 0.03286, saving model to model_.17-0.032859.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 187s 735ms/step - accuracy: 0.9894 - dice_coef: 0.4474 - dice_coef_edema: 0.5579 - dice_coef_enhancing: 0.4872 - dice_coef_necrotic: 0.2617 - loss: 0.0318 - mean_io_u: 0.5170 - precision: 0.9924 - sensitivity: 0.9862 - specificity: 0.9974 - val_accuracy: 0.9894 - val_dice_coef: 0.4576 - val_dice_coef_edema: 0.4846 - val_dice_coef_enhancing: 0.4656 - val_dice_coef_necrotic: 0.3353 - val_loss: 0.0329 - val_mean_io_u: 0.5000 - val_precision: 0.9921 - val_sensitivity: 0.9867 - val_specificity: 0.9973 - learning_rate: 2.0000e-04
# Epoch 18/35
#
# Epoch 18: val_loss improved from 0.03286 to 0.03286, saving model to model_.18-0.032859.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 33s 134ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9894 - val_dice_coef: 0.4576 - val_dice_coef_edema: 0.4846 - val_dice_coef_enhancing: 0.4656 - val_dice_coef_necrotic: 0.3353 - val_loss: 0.0329 - val_mean_io_u: 0.5000 - val_precision: 0.9921 - val_sensitivity: 0.9867 - val_specificity: 0.9973 - learning_rate: 2.0000e-04
# Epoch 19/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 600ms/step - accuracy: 0.9899 - dice_coef: 0.4743 - dice_coef_edema: 0.5633 - dice_coef_enhancing: 0.5237 - dice_coef_necrotic: 0.3411 - loss: 0.0289 - mean_io_u: 0.5200 - precision: 0.9929 - sensitivity: 0.9868 - specificity: 0.9976
# Epoch 19: val_loss improved from 0.03286 to 0.02995, saving model to model_.19-0.029953.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 189s 739ms/step - accuracy: 0.9899 - dice_coef: 0.4743 - dice_coef_edema: 0.5633 - dice_coef_enhancing: 0.5237 - dice_coef_necrotic: 0.3411 - loss: 0.0289 - mean_io_u: 0.5199 - precision: 0.9929 - sensitivity: 0.9868 - specificity: 0.9976 - val_accuracy: 0.9900 - val_dice_coef: 0.4662 - val_dice_coef_edema: 0.5729 - val_dice_coef_enhancing: 0.4387 - val_dice_coef_necrotic: 0.3163 - val_loss: 0.0300 - val_mean_io_u: 0.5000 - val_precision: 0.9917 - val_sensitivity: 0.9881 - val_specificity: 0.9972 - learning_rate: 2.0000e-04
# Epoch 20/35
#
# Epoch 20: val_loss did not improve from 0.02995
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 34s 134ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9900 - val_dice_coef: 0.4662 - val_dice_coef_edema: 0.5729 - val_dice_coef_enhancing: 0.4387 - val_dice_coef_necrotic: 0.3163 - val_loss: 0.0300 - val_mean_io_u: 0.5000 - val_precision: 0.9917 - val_sensitivity: 0.9881 - val_specificity: 0.9972 - learning_rate: 2.0000e-04
# Epoch 21/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 596ms/step - accuracy: 0.9902 - dice_coef: 0.4873 - dice_coef_edema: 0.5951 - dice_coef_enhancing: 0.5415 - dice_coef_necrotic: 0.3416 - loss: 0.0285 - mean_io_u: 0.5184 - precision: 0.9925 - sensitivity: 0.9876 - specificity: 0.9974
# Epoch 21: val_loss improved from 0.02995 to 0.02839, saving model to model_.21-0.028387.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 187s 733ms/step - accuracy: 0.9902 - dice_coef: 0.4873 - dice_coef_edema: 0.5951 - dice_coef_enhancing: 0.5415 - dice_coef_necrotic: 0.3417 - loss: 0.0285 - mean_io_u: 0.5183 - precision: 0.9925 - sensitivity: 0.9876 - specificity: 0.9974 - val_accuracy: 0.9907 - val_dice_coef: 0.4862 - val_dice_coef_edema: 0.5867 - val_dice_coef_enhancing: 0.4878 - val_dice_coef_necrotic: 0.3742 - val_loss: 0.0284 - val_mean_io_u: 0.5000 - val_precision: 0.9929 - val_sensitivity: 0.9882 - val_specificity: 0.9976 - learning_rate: 2.0000e-04
# Epoch 22/35
#
# Epoch 22: val_loss did not improve from 0.02839
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9907 - val_dice_coef: 0.4862 - val_dice_coef_edema: 0.5867 - val_dice_coef_enhancing: 0.4878 - val_dice_coef_necrotic: 0.3742 - val_loss: 0.0284 - val_mean_io_u: 0.5000 - val_precision: 0.9929 - val_sensitivity: 0.9882 - val_specificity: 0.9976 - learning_rate: 2.0000e-04
# Epoch 23/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 593ms/step - accuracy: 0.9901 - dice_coef: 0.4991 - dice_coef_edema: 0.6108 - dice_coef_enhancing: 0.5489 - dice_coef_necrotic: 0.3756 - loss: 0.0278 - mean_io_u: 0.5227 - precision: 0.9927 - sensitivity: 0.9873 - specificity: 0.9975
# Epoch 23: val_loss improved from 0.02839 to 0.02806, saving model to model_.23-0.028055.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 193s 759ms/step - accuracy: 0.9901 - dice_coef: 0.4991 - dice_coef_edema: 0.6108 - dice_coef_enhancing: 0.5489 - dice_coef_necrotic: 0.3756 - loss: 0.0278 - mean_io_u: 0.5226 - precision: 0.9927 - sensitivity: 0.9873 - specificity: 0.9975 - val_accuracy: 0.9904 - val_dice_coef: 0.4826 - val_dice_coef_edema: 0.6119 - val_dice_coef_enhancing: 0.4903 - val_dice_coef_necrotic: 0.3627 - val_loss: 0.0281 - val_mean_io_u: 0.5000 - val_precision: 0.9925 - val_sensitivity: 0.9879 - val_specificity: 0.9975 - learning_rate: 2.0000e-04
# Epoch 24/35
#
# Epoch 24: val_loss improved from 0.02806 to 0.02806, saving model to model_.24-0.028055.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 34s 137ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9904 - val_dice_coef: 0.4826 - val_dice_coef_edema: 0.6119 - val_dice_coef_enhancing: 0.4903 - val_dice_coef_necrotic: 0.3627 - val_loss: 0.0281 - val_mean_io_u: 0.5000 - val_precision: 0.9925 - val_sensitivity: 0.9879 - val_specificity: 0.9975 - learning_rate: 2.0000e-04
# Epoch 25/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - accuracy: 0.9910 - dice_coef: 0.5150 - dice_coef_edema: 0.6242 - dice_coef_enhancing: 0.5697 - dice_coef_necrotic: 0.4024 - loss: 0.0256 - mean_io_u: 0.5234 - precision: 0.9931 - sensitivity: 0.9883 - specificity: 0.9976
# Epoch 25: val_loss improved from 0.02806 to 0.02690, saving model to model_.25-0.026904.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 194s 762ms/step - accuracy: 0.9910 - dice_coef: 0.5150 - dice_coef_edema: 0.6242 - dice_coef_enhancing: 0.5697 - dice_coef_necrotic: 0.4024 - loss: 0.0256 - mean_io_u: 0.5234 - precision: 0.9931 - sensitivity: 0.9883 - specificity: 0.9976 - val_accuracy: 0.9909 - val_dice_coef: 0.5051 - val_dice_coef_edema: 0.6136 - val_dice_coef_enhancing: 0.5220 - val_dice_coef_necrotic: 0.3992 - val_loss: 0.0269 - val_mean_io_u: 0.5000 - val_precision: 0.9933 - val_sensitivity: 0.9885 - val_specificity: 0.9977 - learning_rate: 2.0000e-04
# Epoch 26/35
#
# Epoch 26: val_loss did not improve from 0.02690
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 33s 134ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9909 - val_dice_coef: 0.5051 - val_dice_coef_edema: 0.6136 - val_dice_coef_enhancing: 0.5220 - val_dice_coef_necrotic: 0.3992 - val_loss: 0.0269 - val_mean_io_u: 0.5000 - val_precision: 0.9933 - val_sensitivity: 0.9885 - val_specificity: 0.9977 - learning_rate: 2.0000e-04
# Epoch 27/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 609ms/step - accuracy: 0.9910 - dice_coef: 0.5223 - dice_coef_edema: 0.6359 - dice_coef_enhancing: 0.5701 - dice_coef_necrotic: 0.4208 - loss: 0.0253 - mean_io_u: 0.5239 - precision: 0.9931 - sensitivity: 0.9883 - specificity: 0.9976
# Epoch 27: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 27: val_loss did not improve from 0.02690
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 189s 743ms/step - accuracy: 0.9910 - dice_coef: 0.5223 - dice_coef_edema: 0.6359 - dice_coef_enhancing: 0.5701 - dice_coef_necrotic: 0.4208 - loss: 0.0253 - mean_io_u: 0.5238 - precision: 0.9931 - sensitivity: 0.9883 - specificity: 0.9976 - val_accuracy: 0.9912 - val_dice_coef: 0.5061 - val_dice_coef_edema: 0.6155 - val_dice_coef_enhancing: 0.5335 - val_dice_coef_necrotic: 0.3845 - val_loss: 0.0273 - val_mean_io_u: 0.5000 - val_precision: 0.9929 - val_sensitivity: 0.9891 - val_specificity: 0.9976 - learning_rate: 2.0000e-04
# Epoch 28/35
#
# Epoch 28: val_loss did not improve from 0.02690
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 33s 132ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9912 - val_dice_coef: 0.5061 - val_dice_coef_edema: 0.6155 - val_dice_coef_enhancing: 0.5335 - val_dice_coef_necrotic: 0.3845 - val_loss: 0.0273 - val_mean_io_u: 0.5000 - val_precision: 0.9929 - val_sensitivity: 0.9891 - val_specificity: 0.9976 - learning_rate: 4.0000e-05
# Epoch 29/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 602ms/step - accuracy: 0.9923 - dice_coef: 0.5379 - dice_coef_edema: 0.6724 - dice_coef_enhancing: 0.6018 - dice_coef_necrotic: 0.4315 - loss: 0.0219 - mean_io_u: 0.5247 - precision: 0.9940 - sensitivity: 0.9899 - specificity: 0.9979
# Epoch 29: val_loss improved from 0.02690 to 0.02597, saving model to model_.29-0.025967.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 188s 739ms/step - accuracy: 0.9923 - dice_coef: 0.5380 - dice_coef_edema: 0.6724 - dice_coef_enhancing: 0.6018 - dice_coef_necrotic: 0.4316 - loss: 0.0219 - mean_io_u: 0.5246 - precision: 0.9940 - sensitivity: 0.9899 - specificity: 0.9979 - val_accuracy: 0.9917 - val_dice_coef: 0.5232 - val_dice_coef_edema: 0.6352 - val_dice_coef_enhancing: 0.5602 - val_dice_coef_necrotic: 0.4291 - val_loss: 0.0260 - val_mean_io_u: 0.5000 - val_precision: 0.9934 - val_sensitivity: 0.9893 - val_specificity: 0.9977 - learning_rate: 4.0000e-05
# Epoch 30/35
#
# Epoch 30: val_loss did not improve from 0.02597
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9917 - val_dice_coef: 0.5232 - val_dice_coef_edema: 0.6352 - val_dice_coef_enhancing: 0.5602 - val_dice_coef_necrotic: 0.4291 - val_loss: 0.0260 - val_mean_io_u: 0.5000 - val_precision: 0.9934 - val_sensitivity: 0.9893 - val_specificity: 0.9977 - learning_rate: 4.0000e-05
# Epoch 31/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 609ms/step - accuracy: 0.9922 - dice_coef: 0.5487 - dice_coef_edema: 0.6633 - dice_coef_enhancing: 0.6185 - dice_coef_necrotic: 0.4864 - loss: 0.0218 - mean_io_u: 0.5247 - precision: 0.9939 - sensitivity: 0.9899 - specificity: 0.9979
# Epoch 31: val_loss improved from 0.02597 to 0.02565, saving model to model_.31-0.025645.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 189s 740ms/step - accuracy: 0.9922 - dice_coef: 0.5487 - dice_coef_edema: 0.6634 - dice_coef_enhancing: 0.6185 - dice_coef_necrotic: 0.4863 - loss: 0.0218 - mean_io_u: 0.5246 - precision: 0.9939 - sensitivity: 0.9899 - specificity: 0.9979 - val_accuracy: 0.9918 - val_dice_coef: 0.5307 - val_dice_coef_edema: 0.6536 - val_dice_coef_enhancing: 0.5684 - val_dice_coef_necrotic: 0.4407 - val_loss: 0.0256 - val_mean_io_u: 0.5000 - val_precision: 0.9933 - val_sensitivity: 0.9896 - val_specificity: 0.9977 - learning_rate: 4.0000e-05
# Epoch 32/35
#
# Epoch 32: val_loss did not improve from 0.02565
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 32s 130ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9918 - val_dice_coef: 0.5307 - val_dice_coef_edema: 0.6536 - val_dice_coef_enhancing: 0.5684 - val_dice_coef_necrotic: 0.4407 - val_loss: 0.0256 - val_mean_io_u: 0.5000 - val_precision: 0.9933 - val_sensitivity: 0.9896 - val_specificity: 0.9977 - learning_rate: 4.0000e-05
# Epoch 33/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 601ms/step - accuracy: 0.9921 - dice_coef: 0.5567 - dice_coef_edema: 0.6659 - dice_coef_enhancing: 0.6247 - dice_coef_necrotic: 0.4954 - loss: 0.0220 - mean_io_u: 0.5236 - precision: 0.9937 - sensitivity: 0.9898 - specificity: 0.9978
# Epoch 33: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 33: val_loss did not improve from 0.02565
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 195s 767ms/step - accuracy: 0.9921 - dice_coef: 0.5567 - dice_coef_edema: 0.6659 - dice_coef_enhancing: 0.6247 - dice_coef_necrotic: 0.4953 - loss: 0.0220 - mean_io_u: 0.5235 - precision: 0.9937 - sensitivity: 0.9898 - specificity: 0.9978 - val_accuracy: 0.9917 - val_dice_coef: 0.5331 - val_dice_coef_edema: 0.6488 - val_dice_coef_enhancing: 0.5522 - val_dice_coef_necrotic: 0.4135 - val_loss: 0.0268 - val_mean_io_u: 0.5000 - val_precision: 0.9929 - val_sensitivity: 0.9901 - val_specificity: 0.9976 - learning_rate: 4.0000e-05
# Epoch 34/35
#
# Epoch 34: val_loss did not improve from 0.02565
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 33s 130ms/step - accuracy: 0.0000e+00 - dice_coef: 0.0000e+00 - dice_coef_edema: 0.0000e+00 - dice_coef_enhancing: 0.0000e+00 - dice_coef_necrotic: 0.0000e+00 - loss: 0.0000e+00 - mean_io_u: 0.0000e+00 - precision: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 0.0000e+00 - val_accuracy: 0.9917 - val_dice_coef: 0.5331 - val_dice_coef_edema: 0.6488 - val_dice_coef_enhancing: 0.5522 - val_dice_coef_necrotic: 0.4135 - val_loss: 0.0268 - val_mean_io_u: 0.5000 - val_precision: 0.9929 - val_sensitivity: 0.9901 - val_specificity: 0.9976 - learning_rate: 8.0000e-06
# Epoch 35/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 604ms/step - accuracy: 0.9927 - dice_coef: 0.5691 - dice_coef_edema: 0.6946 - dice_coef_enhancing: 0.6366 - dice_coef_necrotic: 0.4921 - loss: 0.0205 - mean_io_u: 0.5248 - precision: 0.9940 - sensitivity: 0.9906 - specificity: 0.9979
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
#
# Epoch 35: val_loss did not improve from 0.02565
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 222s 737ms/step - accuracy: 0.9927 - dice_coef: 0.5690 - dice_coef_edema: 0.6946 - dice_coef_enhancing: 0.6366 - dice_coef_necrotic: 0.4921 - loss: 0.0205 - mean_io_u: 0.5247 - precision: 0.9940 - sensitivity: 0.9906 - specificity: 0.9979 - val_accuracy: 0.9918 - val_dice_coef: 0.5370 - val_dice_coef_edema: 0.6581 - val_dice_coef_enhancing: 0.5635 - val_dice_coef_necrotic: 0.4350 - val_loss: 0.0260 - val_mean_io_u: 0.5000 - val_precision: 0.9931 - val_sensitivity: 0.9900 - val_specificity: 0.9977 - learning_rate: 8.0000e-06

# %%
model.save("Brain_tumor_segmentation_model.keras")

# %%
model = keras.models.load_model('/content/Brain_tumor_segmentation_model.keras',
                                   custom_objects={"accuracy" : tf.keras.metrics.MeanIoU(num_classes=4),
                                                   "dice_coef" : dice_coef,
                                                   "precision" : precision,
                                                   "sensitivity" :sensitivity,
                                                   "specificity" :specificity,
                                                   "dice_coef_necrotic" : dice_coef_necrotic,
                                                   "dice_coef_edema" : dice_coef_edema,
                                                   "dice_coef_enhancing" : dice_coef_enhancing
                                                  }, compile=False)

# %%
history = pd.read_csv('/content/training.log', sep=',', engine='python')

hist=history

acc=hist['accuracy']
val_acc=hist['val_accuracy']

epoch=range(len(acc))

loss=hist['loss']
val_loss=hist['val_loss']

train_dice=hist['dice_coef']
val_dice=hist['val_dice_coef']

f,ax=plt.subplots(1,4,figsize=(16,8))

ax[0].plot(epoch,acc,'b',label='Training Accuracy')
ax[0].plot(epoch,val_acc,'r',label='Validation Accuracy')
ax[0].legend()

ax[1].plot(epoch,loss,'b',label='Training Loss')
ax[1].plot(epoch,val_loss,'r',label='Validation Loss')
ax[1].legend()

ax[2].plot(epoch,train_dice,'b',label='Training dice coef')
ax[2].plot(epoch,val_dice,'r',label='Validation dice coef')
ax[2].legend()

ax[3].plot(epoch,hist['mean_io_u'],'b',label='Training mean IOU')
ax[3].plot(epoch,hist['val_mean_io_u'],'r',label='Validation mean IOU')
ax[3].legend()

plt.show()

# %%
model.save_weights('model_best.weights.h5')

# %%
# Compile a model and load our saved weights
IMG_SIZE = 128
input_layer = Input((IMG_SIZE, IMG_SIZE, 2))

best_saved_model = build_unet(input_layer, 'he_normal', 0.2)
# model.load_weights()
best_saved_model.compile(loss="categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, dice_coef_edema, dice_coef_enhancing])

# /content/model_.31-0.025645.weights.h5
best_saved_model.load_weights(filepath = '/content/model_best.weights.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py:576: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 0 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
def imageLoader(path):
    image = nib.load(path).get_fdata()
    X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))
    for j in range(VOLUME_SLICES):
        X[j +VOLUME_SLICES*c,:,:,0] = cv2.resize(image[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));
        X[j +VOLUME_SLICES*c,:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));

        y[j +VOLUME_SLICES*c] = seg[:,:,j+VOLUME_START_AT];
    return np.array(image)

# %%
def loadDataFromDir(path, list_of_files, mriType, n_images):
    scans = []
    masks = []
    for i in list_of_files[:n_images]:
        fullPath = glob.glob( i + '/*'+ mriType +'*')[0]
        currentScanVolume = imageLoader(fullPath)
        currentMaskVolume = imageLoader( glob.glob( i + '/*seg*')[0] )
        # for each slice in 3D volume, find also it's mask
        for j in range(0, currentScanVolume.shape[2]):
            scan_img = cv2.resize(currentScanVolume[:,:,j], dsize=(IMG_SIZE,IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')
            mask_img = cv2.resize(currentMaskVolume[:,:,j], dsize=(IMG_SIZE,IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')
            scans.append(scan_img[..., np.newaxis])
            masks.append(mask_img[..., np.newaxis])
    return np.array(scans, dtype='float32'), np.array(masks, dtype='float32')

# %%
def predictByPath(case_path,case):
    files = next(os.walk(case_path))[2]
    X = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE, 2))

    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_flair.nii');
    flair=nib.load(vol_path).get_fdata()

    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_t1ce.nii');
    ce=nib.load(vol_path).get_fdata()


    for j in range(VOLUME_SLICES):
        X[j,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        X[j,:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))

    return model.predict(X/np.max(X), verbose=1)

# %%
def showPredictsById(case, start_slice = 60):
    path = f"/content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_{case}"
    gt = nib.load(os.path.join(path, f'BraTS20_Training_{case}_seg.nii')).get_fdata()
    origImage = nib.load(os.path.join(path, f'BraTS20_Training_{case}_flair.nii')).get_fdata()
    p = predictByPath(path,case)

    core = p[:,:,:,1]
    edema= p[:,:,:,2]
    enhancing = p[:,:,:,3]

    plt.figure(figsize=(18, 50))
    f, axarr = plt.subplots(1,6, figsize = (18, 50))

    for i in range(6): # for each image, add brain background
        axarr[i].imshow(cv2.resize(origImage[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE)), cmap="gray", interpolation='none')

    axarr[0].imshow(cv2.resize(origImage[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE)), cmap="gray")
    axarr[0].title.set_text('Original image flair')
    curr_gt=cv2.resize(gt[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation = cv2.INTER_NEAREST)
    axarr[1].imshow(curr_gt, cmap="Reds", interpolation='none', alpha=0.3) # ,alpha=0.3,cmap='Reds'
    axarr[1].title.set_text('Ground truth')
    axarr[2].imshow(p[start_slice,:,:,1:4], cmap="Reds", interpolation='none', alpha=0.3)
    axarr[2].title.set_text('all classes predicted')
    axarr[3].imshow(edema[start_slice,:,:], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[3].title.set_text(f'{SEGMENT_CLASSES[1]} predicted')
    axarr[4].imshow(core[start_slice,:,], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[4].title.set_text(f'{SEGMENT_CLASSES[2]} predicted')
    axarr[5].imshow(enhancing[start_slice,:,], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[5].title.set_text(f'{SEGMENT_CLASSES[3]} predicted')
    plt.show()

# %%
showPredictsById(case=test_ids[0][-3:])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step

# %%
showPredictsById(case=test_ids[1][-3:])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step

# %%
showPredictsById(case=test_ids[2][-3:])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step

# %%
showPredictsById(case=test_ids[3][-3:])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step

# %%
showPredictsById(case=test_ids[4][-3:])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step

# %%
showPredictsById(case=test_ids[5][-3:])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step

# %%
showPredictsById(case=test_ids[6][-3:])
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step

# %%
def predict_segmentation(sample_path):
    # Load NIfTI (.nii) files of the sample (patient)
    t1ce_path = sample_path + '_t1ce.nii'
    flair_path = sample_path + '_flair.nii'

    # Extract the data from these paths
    t1ce = nib.load(t1ce_path).get_fdata()
    flair = nib.load(flair_path).get_fdata()

    # Create an empty array
    X = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE, 2))

    # Perform the same operations as our DataGenerator, to keep the same input shape
    for j in range(VOLUME_SLICES):
        X[j,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        X[j,:,:,1] = cv2.resize(t1ce[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))

    # Send our images to the CNN model and return predicted segmentation
    return model.predict(X/np.max(X), verbose=1)

# %%
def show_predicted_segmentations(samples_list, slice_to_plot, cmap, norm):
    # Choose a random patient
    random_sample = random.choice(samples_list)

    # Get path of this patient
    random_sample_path = os.path.join(TRAIN_DATASET_PATH, random_sample, random_sample)

    # Predict patient's segmentation
    predicted_seg = predict_segmentation(random_sample_path)

    # Load patient's original segmentation (Ground truth)
    seg_path = random_sample_path + '_seg.nii'
    seg = nib.load(seg_path).get_fdata()

    # Resize original segmentation to the same dimensions of the predictions. (Add VOLUME_START_AT because original segmentation contains 155 slices vs only 75 for our prediction)
    seg=cv2.resize(seg[:,:,slice_to_plot+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation = cv2.INTER_NEAREST)

    # Differentiate segmentations by their labels
    all = predicted_seg[slice_to_plot,:,:,1:4] # Deletion of class 0 (Keep only Core + Edema + Enhancing classes)
    zero = predicted_seg[slice_to_plot,:,:,0] # Isolation of class 0, Background (kind of useless, it is the opposite of the "all")
    first = predicted_seg[slice_to_plot,:,:,1] # Isolation of class 1, Core
    second = predicted_seg[slice_to_plot,:,:,2] # Isolation of class 2, Edema
    third = predicted_seg[slice_to_plot,:,:,3] # Isolation of class 3, Enhancing

    # Plot Original segmentation & predicted segmentation
    print("Patient number: ", random_sample)
    fig, axstest = plt.subplots(1, 6, figsize=(25, 20))

    # Original segmentation
    axstest[0].imshow(seg, cmap, norm)
    axstest[0].set_title('Original Segmentation')

    # Layers 1, 2, 3
    axstest[1].imshow(all, cmap, norm)
    axstest[1].set_title('Predicted Segmentation - all classes')

    # Layer 0
    axstest[2].imshow(zero)
    axstest[2].set_title('Predicted Segmentation - Not Tumor')

    # Layer 1
    axstest[3].imshow(first)
    axstest[3].set_title('Predicted Segmentation - Necrotic/Core')

    # Layer 2
    axstest[4].imshow(second)
    axstest[4].set_title('Predicted Segmentation - Edema')

    # Layer 3
    axstest[5].imshow(third)
    axstest[5].set_title('Predicted Segmentation - Enhancing')

    # Add space between subplots
    plt.subplots_adjust(wspace=0.8)

    plt.show()

# %%
show_predicted_segmentations(test_ids, 60, cmap, norm)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Patient number:  BraTS20_Training_244

# %%
show_predicted_segmentations(test_ids, 60, cmap, norm)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Patient number:  BraTS20_Training_114

# %%
show_predicted_segmentations(test_ids, 65, cmap, norm)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Patient number:  BraTS20_Training_046

# %%
case = test_ids[3][-3:]
path = f"/content/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_{case}"
gt = nib.load(os.path.join(path, f'BraTS20_Training_{case}_seg.nii')).get_fdata()
p = predictByPath(path,case)

core = p[:,:,:,1]
edema= p[:,:,:,2]
enhancing = p[:,:,:,3]

i=40 # slice at
eval_class = 2 #     0 : 'NOT tumor',  1 : 'ENHANCING',    2 : 'CORE',    3 : 'WHOLE'

gt[gt != eval_class] = 1 # use only one class for per class evaluation

resized_gt = cv2.resize(gt[:,:,i+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

plt.figure()
f, axarr = plt.subplots(1,2)
axarr[0].imshow(resized_gt, cmap="gray")
axarr[0].title.set_text('ground truth')
axarr[1].imshow(p[i,:,:,eval_class], cmap="gray")
axarr[1].title.set_text(f'predicted class: {SEGMENT_CLASSES[eval_class]}')
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step

# %%
# Evaluate the model on the test data
model.compile(loss="categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=0.001),
              metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, dice_coef_edema, dice_coef_enhancing])

results = model.evaluate(test_generator, batch_size=100, callbacks= callbacks)

descriptions = ["Loss", "Accuracy", "MeanIOU", "Dice coefficient", "Precision", "Sensitivity", "Specificity", "Dice coef Necrotic", "Dice coef Edema", "Dice coef Enhancing"]

# Combine results list and descriptions list
results_list = zip(results, descriptions)

# Display each metric with its description
print("\nModel evaluation on the test set:")
print("==================================")
for i, (metric, description) in enumerate(results_list):
    print(f"{description} : {round(metric, 4)}")
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 30s 506ms/step - accuracy: 0.9911 - dice_coef: 0.5511 - dice_coef_edema: 0.7131 - dice_coef_enhancing: 0.5858 - dice_coef_necrotic: 0.4254 - loss: 0.0285 - mean_io_u_3: 0.6313 - precision: 0.9926 - sensitivity: 0.9888 - specificity: 0.9975
#
# Model evaluation on the test set:
# ==================================
# Loss : 0.0348
# Accuracy : 0.9903
# MeanIOU : 0.5
# Dice coefficient : 0.5612
# Precision : 0.9919
# Sensitivity : 0.988
# Specificity : 0.9972
# Dice coef Necrotic : 0.4701
# Dice coef Edema : 0.6746
# Dice coef Enhancing : 0.6251

# %%
model.save('Brain_tumor_seg_model_best.h5')
model.save('Brain_tumor_seg_model_best.keras')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
